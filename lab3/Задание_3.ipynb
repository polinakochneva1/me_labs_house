# %% [markdown]
# <a href="https://colab.research.google.com/github/polinakochneva1/me_labs_house/blob/main/lab3/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 3

# %% [markdown]
# ##Обработка пропущенных значений

# %% [markdown]
# Обработайте пропущенные значения:
#
#
# * Удалите пропущенные значения
# * Заполните при помощи медианы, среднего для числовых значений
# * Заполните при помощи моды для категориальных значений
# * Интерполируйте
# Выведите статистку после каждого метода и объясните

# %%
# !pip install scikit-learn

# %%
import pandas as pd

df = pd.read_csv('/content/global-data-on-sustainable-energy.csv')
df
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %%
#Удаление
df_cleaned = df.dropna()
df_cleaned
# Out:
#           Entity  Year  Access to electricity (% of population)  \
# 43       Algeria  2001                                 98.96687
# 44       Algeria  2002                                 98.95306
# 45       Algeria  2003                                 98.93401
# 46       Algeria  2004                                 98.91208
# 47       Algeria  2005                                 98.88961
# ...          ...   ...                                      ...
# 3559  Uzbekistan  2015                                100.00000
# 3560  Uzbekistan  2016                                100.00000
# 3561  Uzbekistan  2017                                100.00000
# 3562  Uzbekistan  2018                                100.00000
# 3563  Uzbekistan  2019                                100.00000
#
#       Access to clean fuels for cooking  \
# 43                                97.30
# 44                                97.80
# 45                                98.00
# ...

# %% [markdown]
# **Мы удалили все строки, которые содержали в одном из столбце значение NaN. Если посмотреть на первую таблицу, можно увидить данное значение в 4 строке, в колонке Financial flows to developing countries (US $), следовательно мы удалили эту строку.**

# %%
#Заполнение при помощи среднего
df_filled_mean = df.fillna(df.mean())

df_filled_mean
# Out:
# <ipython-input-8-20526bfdd642>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_filled_mean = df.fillna(df.mean())
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# ...

# %% [markdown]
# **Тк у категориальных переменных нет среднего,
# его надо или заменить с помощью моды, или преобразовать в числа. Мы заменили NaN средним значением**

# %%
#Заполнение при помощи медианы
df_filled_median = df.fillna(df.median())

df_filled_median
# Out:
# <ipython-input-9-1d6bd374d546>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_filled_median = df.fillna(df.median())
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# ...

# %% [markdown]
# **Тк у категориальных переменных нет медианы,
# её надо или заменить с помощью моды, или преобразовать в числа. Если обратиться к первой таблицы, можно так же увидить разницу в 4 строке, мы заменили значение NaN медианой**

# %%
#Заполнение при помощи моды
df_filled_mode = df.fillna(df["Year"].mode()[0])

df_filled_mode
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %% [markdown]
# **Мы заполнили столбец Year при помощи моды. Она возвращает объект Series, так как значений моды может быть несколько**

# %%
#Заполнение при помощи интерполяции
df_interpolated = df.interpolate()

df_interpolated
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %% [markdown]
# **Надо преобразовывать, тк интерполяция не работает для категориальных значений.Применяем линейную интерполяцию для заполнения пропущенных значений**

# %% [markdown]
# **Объясните**

# %% [markdown]
# **Все объяснения предоставлены под каждой из таблиц**

# %% [markdown]
# ##Поиск выбросов и аномалий

# %% [markdown]
# **Те, кто выполняет задания со * делают поиск выбросов с помощью написанного ранее класса**
#
# Найти выбросы по числовой переменной (использовать метод основанный на среднем и на межквартильном размахе). Объясните результат
#
# Вывести статистику с выбросами и без. Сравните и объясните результат

# %%
#Методом среднего

# %%
#При помощи межквартильного размаха

# %%
#Статистика и объяснение

# %% [markdown]
# **Объяснения**

# %% [markdown]
# ##Дубликаты

# %% [markdown]
# Проверьте датафрейм на дубликаты и удалите их, если дублей нет - создайте.

# %%
#Проверка на дубли
df_duplicated = df[df.duplicated()]
df_duplicated
# Out:
#                   Entity  Year  Access to electricity (% of population)  \
# 0            Afghanistan  2000                                 1.613591
# 1            Afghanistan  2001                                 4.074574
# 2            Afghanistan  2002                                 9.409158
# 3            Afghanistan  2003                                14.738506
# 4            Afghanistan  2004                                20.064968
# ..                   ...   ...                                      ...
# 96   Antigua and Barbuda  2012                               100.000000
# 97   Antigua and Barbuda  2013                               100.000000
# 98   Antigua and Barbuda  2014                               100.000000
# 99   Antigua and Barbuda  2015                               100.000000
# 100  Antigua and Barbuda  2016                               100.000000
#
#      Access to clean fuels for cooking  \
# 0                                  6.2
# ...

# %% [markdown]
# **Дубликаты найдены в 101 строке**

# %%
#Удаление дублей
df = df.drop_duplicates()
df_no_duplicates = df[df.duplicated()]
df_no_duplicates
# Out:
# Empty DataFrame
# Columns: [Entity, Year, Access to electricity (% of population), Access to clean fuels for cooking, Renewable-electricity-generating-capacity-per-capita, Financial flows to developing countries (US $), Renewable energy share in the total final energy consumption (%), Electricity from fossil fuels (TWh), Electricity from nuclear (TWh), Electricity from renewables (TWh), Low-carbon electricity (% electricity), Primary energy consumption per capita (kWh/person), Energy intensity level of primary energy (MJ/$2017 PPP GDP), Value_co2_emissions_kt_by_country, Renewables (% equivalent primary energy), gdp_growth, gdp_per_capita, Density\n(P/Km2), Land Area(Km2), Latitude, Longitude]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# **Мы удалили все дубликаты**

# %% [markdown]
# ## Преобразование признаков

# %% [markdown]
# Масштабируйте числовые признаки через MinMaxScaler, StandardScaler

# %%
# Получаем числовые признаки
num_features = df.select_dtypes(include=['float64']).columns
num_features
# Out:
# Index(['Access to electricity (% of population)',
#        'Access to clean fuels for cooking',
#        'Renewable-electricity-generating-capacity-per-capita',
#        'Financial flows to developing countries (US $)',
#        'Renewable energy share in the total final energy consumption (%)',
#        'Electricity from fossil fuels (TWh)', 'Electricity from nuclear (TWh)',
#        'Electricity from renewables (TWh)',
#        'Low-carbon electricity (% electricity)',
#        'Primary energy consumption per capita (kWh/person)',
#        'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
#        'Value_co2_emissions_kt_by_country',
#        'Renewables (% equivalent primary energy)', 'gdp_growth',
#        'gdp_per_capita', 'Land Area(Km2)', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# Выбираем индекс и выводим первичные уникальные значения в числовом призанке
df.Longitude.unique()
# Out:
# array([  67.709953  ,   20.168331  ,    1.659626  ,   17.873887  ,
#         -61.796428  ,  -63.616672  ,   45.038189  ,  -69.96833   ,
#         133.775136  ,   14.550072  ,   47.576927  ,  -78.035889  ,
#          50.5577    ,   90.356331  ,  -59.543198  ,   27.953389  ,
#           4.469936  ,  -88.49765   ,    2.315834  ,  -64.790337  ,
#          90.433601  ,   17.679076  ,   24.684866  ,  -51.92528   ,
#          25.48583   ,   -1.561593  ,   29.918886  ,  104.990963  ,
#          12.354722  , -106.346771  ,   81.2524    ,   20.939444  ,
#          18.732207  ,  -71.542969  ,  104.195397  ,  -74.297333  ,
#          43.3333    ,   13.7289    ,  -83.753428  ,   15.2       ,
#         -77.781167  ,   33.429859  ,   15.472962  ,    9.501785  ,
#          42.590275  ,  -61.370976  ,  -70.162651  ,  -78.183406  ,
#          30.802498  ,  -88.89653   ,   10.267895  ,   39.782334  ,
#          25.013607  ,   31.465866  ,   40.489673  ,  178.065032  ,
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
# MinMax масштабирование
scaler_minmax = MinMaxScaler()
df_minmax_scaled = df.copy()
df_minmax_scaled[num_features] = scaler_minmax.fit_transform(df[num_features])
df_minmax_scaled.Longitude.unique()
# Out:
# array([0.68761236, 0.55303392, 0.5006404 , 0.54653892, 0.32101218,
#        0.31585953, 0.62343427, 0.29787957, 0.87462638, 0.53713003,
#        0.6306208 , 0.27504233, 0.63905862, 0.7517186 , 0.32739051,
#        0.57507147, 0.50859569, 0.2454277 , 0.50249796, 0.31253717,
#        0.75193733, 0.54598746, 0.5658191 , 0.34895493, 0.56808643,
#        0.49152194, 0.5806353 , 0.79314558, 0.53091555, 0.1949013 ,
#        0.72594765, 0.55521675, 0.54896861, 0.29342216, 0.79089353,
#        0.28562524, 0.61860815, 0.5348055 , 0.2588574 , 0.53896982,
#        0.27576338, 0.59057399, 0.5397425 , 0.52283959, 0.61650484,
#        0.32221653, 0.2973295 , 0.27462474, 0.58313659, 0.24429857,
#        0.52500826, 0.60855626, 0.56674968, 0.58501442, 0.61055856,
#        1.        , 0.56882899, 0.50220899,        nan, 0.52880585,
#        0.44904633, 0.61867494, 0.52552807, 0.49304601, 0.55772159,
#        0.32134459, 0.2405217 , 0.46849364, 0.45297046, 0.32912581,
# ...

# %%
from sklearn.preprocessing import StandardScaler
# Standard масштабирование
scaler_std = StandardScaler()
df_std_scaled = df.copy()
df_std_scaled[num_features] = scaler_std.fit_transform(df[num_features])
df_std_scaled.Longitude.unique()
# Out:
# array([ 7.97226607e-01,  8.05805356e-02, -1.98421109e-01,  4.59939101e-02,
#        -1.15496255e+00, -1.18240105e+00,  4.55470690e-01, -1.27814643e+00,
#         1.79309826e+00, -4.10953319e-03,  4.93739822e-01, -1.39975744e+00,
#         5.38672224e-01,  1.13859985e+00, -1.12099719e+00,  1.97933099e-01,
#        -1.56058279e-01, -1.55745883e+00, -1.88529379e-01, -1.20009297e+00,
#         1.13976463e+00,  4.30573140e-02,  1.48663132e-01, -1.00616411e+00,
#         1.60736925e-01, -2.46978012e-01,  2.27561153e-01,  1.35920342e+00,
#        -3.72024081e-02, -1.82651785e+00,  1.00136650e+00,  9.22043523e-02,
#         5.89322918e-02, -1.30188266e+00,  1.34721100e+00, -1.34340216e+00,
#         4.29771062e-01, -1.64879432e-02, -1.48594406e+00,  5.68753153e-03,
#        -1.39591774e+00,  2.80485830e-01,  9.80218173e-03, -8.02078002e-02,
#         4.18570646e-01, -1.14854926e+00, -1.28107564e+00, -1.40198112e+00,
# ...

# %%
df_scaled = df.copy() # копируем df, чтобы по ссылке не изменять оригинальный
df_scaled[num_features] = df_std_scaled[num_features]
df_scaled
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                -2.554231
# 1     Afghanistan  2001                                -2.472934
# 2     Afghanistan  2002                                -2.296709
# 3     Afghanistan  2003                                -2.120656
# 4     Afghanistan  2004                                -1.944699
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                -1.201530
# 3645     Zimbabwe  2017                                -1.148116
# 3646     Zimbabwe  2018                                -1.102066
# 3647     Zimbabwe  2019                                -1.062133
# 3648     Zimbabwe  2020                                -0.865043
#
#       Access to clean fuels for cooking  \
# 0                             -1.461530
# 1                             -1.435914
# 2                             -1.410298
# ...

# %% [markdown]
# Масштабируйте категориальные признаки через OneHotEncoder

# %%
# Объявим категориальные признаки
df = df.astype({'Access to electricity (% of population)': 'category',
                'Access to clean fuels for cooking': 'category',
                'Renewable-electricity-generating-capacity-per-capita': 'category',
                'Financial flows to developing countries (US $)': 'category',
                'Renewable energy share in the total final energy consumption (%)': 'category',
                'Electricity from fossil fuels (TWh)': 'category',
                'Electricity from nuclear (TWh)': 'category',
                'Electricity from renewables (TWh)': 'category',
                'Low-carbon electricity (% electricity)': 'category',
                'Primary energy consumption per capita (kWh/person)': 'category',
                'Energy intensity level of primary energy (MJ/$2017 PPP GDP)': 'category',
                'Value_co2_emissions_kt_by_country': 'category',
                'Renewables (% equivalent primary energy)': 'category',
                'gdp_growth': 'category',
                'gdp_per_capita': 'category',
                'Land Area(Km2)': 'category',
                'Latitude': 'category',
                'Longitude': 'category' })
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3649 entries, 0 to 3648
# Data columns (total 21 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Entity                                                            3649 non-null   object
#  1   Year                                                              3649 non-null   int64
#  2   Access to electricity (% of population)                           3639 non-null   category
#  3   Access to clean fuels for cooking                                 3480 non-null   category
#  4   Renewable-electricity-generating-capacity-per-capita              2718 non-null   category
#  5   Financial flows to developing countries (US $)                    1560 non-null   category
#  6   Renewable energy share in the total final energy consumption (%)  3455 non-null   category
# ...

# %%
cat_features = df.select_dtypes(include=['category']).columns
# Преобразование с использованием One-Hot Encoding
df_cat_encoded = pd.get_dummies(df, columns=cat_features, drop_first=True)

# Удаление исходных категориальных признаков
cat_features
# Out:
# Index(['Access to electricity (% of population)',
#        'Access to clean fuels for cooking',
#        'Renewable-electricity-generating-capacity-per-capita',
#        'Financial flows to developing countries (US $)',
#        'Renewable energy share in the total final energy consumption (%)',
#        'Electricity from fossil fuels (TWh)', 'Electricity from nuclear (TWh)',
#        'Electricity from renewables (TWh)',
#        'Low-carbon electricity (% electricity)',
#        'Primary energy consumption per capita (kWh/person)',
#        'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
#        'Value_co2_emissions_kt_by_country',
#        'Renewables (% equivalent primary energy)', 'gdp_growth',
#        'gdp_per_capita', 'Land Area(Km2)', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder
# Применяем OneHotEncoder
encoder = OneHotEncoder(sparse=False, drop='first')
encoded_features = encoder.fit_transform(df[cat_features])

# Получаем имена новых признаков
encoded_columns = encoder.get_feature_names_out(cat_features)
encoded_columns
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# array(['Access to electricity (% of population)_1.2537057',
#        'Access to electricity (% of population)_1.2792896',
#        'Access to electricity (% of population)_1.613591', ...,
#        'Longitude_177.64933', 'Longitude_178.065032', 'Longitude_nan'],
#       dtype=object)

# %% [markdown]
# ##Задание для гениев*

# %% [markdown]
# Реализовать расчет корреляции Спирмана

# %%
#Функция по расчету тут

# %%
#Пример использования тут и объяснение принципа работы

# %% [markdown]
# ###Пример реализации

# %%
import pandas as pd
import numpy as np


def corr_pearson(column_1, column_2):
  cov = np.cov(column_1, column_2)
  return cov/(column_1.std() * column_2.std())

# %%
data = {
    'Рост': [170, 155, 180, 162, 175],
    'Вес': [65, 50, 75, 55, 70]
}
df = pd.DataFrame(data)
df
# Out:
#    Рост  Вес
# 0   170   65
# 1   155   50
# 2   180   75
# 3   162   55
# 4   175   70

# %%
corr_pearson(df["Рост"], df["Вес"])
# Out:
# array([[0.96593129, 0.99674864],
#        [0.99674864, 1.03527033]])
